# %%
import pandas as pd

# %% [markdown]
# # Generación DataFrames

# %% [markdown]
# Se desea crear el siguiente DataFrame. Debe generarlo de diferentes maneras
#
# |   | Fruta   | Color     | Precio |
# |---|---------|-----------|--------|
# | 0 | Manzana | rojo      | 1.5    |
# | 1 | Naranja | naranja   | 2.0    |
# | 2 | Banana  | amarillo  | 3.4    |
# | 3 | Limon   | amarillo  | 2.6    |

# %% [markdown]
# 1. A partir de un diccionario que tenga en las claves el nombre de las columnas

# %%
dicc = {
    "Fruta": ["Manzana", "Naranja", "Banana", "Limon"],
    "Color": ["rojo", "naranja", "amarillo", "amarillo"],
    "Precio": [1.5, 2, 3.4, 2.6]
}
pd.DataFrame(dicc)
# Out:
#      Fruta     Color  Precio
# 0  Manzana      rojo     1.5
# 1  Naranja   naranja     2.0
# 2   Banana  amarillo     3.4
# 3    Limon  amarillo     2.6

# %% [markdown]
# 2. A partir de un diccionario que tenga en las claves el indice de las filas (ver from_dict)

# %%
dicc = {
    "Fruta": ["Manzana", "Naranja", "Banana", "Limon"],
    "Color": ["rojo", "naranja", "amarillo", "amarillo"],
    "Precio": [1.5, 2, 3.4, 2.6]
}
pd.DataFrame.from_dict(dicc, orient = "index")
# Out:
#               0        1         2         3
# Fruta   Manzana  Naranja    Banana     Limon
# Color      rojo  naranja  amarillo  amarillo
# Precio      1.5        2       3.4       2.6

# %% [markdown]
# 3. A partir de un diccionario que tenga en las claves el nombre de las columnas, pero que sea un diccionario que tenga además la clave "costo" con los valores (1,1.5,3,2). Por lo que deberá seleccionar únicamente las columnas que le interesen de dicho diccionario

# %%
dicc = {
    "Fruta": ["Manzana", "Naranja", "Banana", "Limon"],
    "Color": ["rojo", "naranja", "amarillo", "amarillo"],
    "Precio": [1.5, 2, 3.4, 2.6],
    "Costo": [1, 1.5, 3, 2]
}
pd.DataFrame(dicc,columns = ["Fruta", "Color", "Precio"])
# Out:
#      Fruta     Color  Precio
# 0  Manzana      rojo     1.5
# 1  Naranja   naranja     2.0
# 2   Banana  amarillo     3.4
# 3    Limon  amarillo     2.6

# %% [markdown]
# 4. A partir de una lista

# %%
lista = [["Manzana","rojo",1.5], ["Naranja","naranja",2], ["Banana","amarillo",3.4], ["Limon","amarillo",2.6]]
pd.DataFrame(
    lista,
    columns = ["Fruta", "Color", "Precio"]
)
# Out:
#      Fruta     Color  Precio
# 0  Manzana      rojo     1.5
# 1  Naranja   naranja     2.0
# 2   Banana  amarillo     3.4
# 3    Limon  amarillo     2.6

# %% [markdown]
# 5. A partir de una lista de diccionarios

# %%
lista = [
    {"Fruta": "Manzana","Color": "rojo"    ,"Precio": 1.5}, 
    {"Fruta": "Naranja","Color": "naranja" ,"Precio": 2}, 
    {"Fruta": "Banana" ,"Color": "amarillo","Precio": 3.4}, 
    {"Fruta": "Limon"  ,"Color": "amarillo","Precio": 2.6}
]
pd.DataFrame(
    lista
)
# Out:
#      Fruta     Color  Precio
# 0  Manzana      rojo     1.5
# 1  Naranja   naranja     2.0
# 2   Banana  amarillo     3.4
# 3    Limon  amarillo     2.6

# %% [markdown]
# 6. A partir de una lista de tuplas generada con la función zip

# %%
Fruta  = ["Manzana", "Naranja", "Banana", "Limon"]
Color  = ["rojo", "naranja", "amarillo", "amarillo"]
Precio = [1.5, 2, 3.4, 2.6]

items = list(zip(Fruta,Color,Precio))
pd.DataFrame(
    items,
    columns = ["Fruta", "Color", "Precio"]
)
# Out:
#      Fruta     Color  Precio
# 0  Manzana      rojo     1.5
# 1  Naranja   naranja     2.0
# 2   Banana  amarillo     3.4
# 3    Limon  amarillo     2.6

# %% [markdown]
# # Analisis de DataFrame

# %% [markdown]
# Todas las preguntas serán en base al dataframe data

# %%
# Base de datos de instituciones educativas en colombia
data = pd.read_csv('https://www.datos.gov.co/api/views/qijw-htwa/rows.csv?accessType=DOWNLOAD')

# %% [markdown]
# 1. Mostrar las primeras 5 filas del DataFrame

# %%
data.head(5)
# Out:
#     año secretaria                              nombreestablecimiento    zona  \
# 0  2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...  URBANA
# 1  2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL  URBANA
# 2  2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA  URBANA
# 3  2016     BOGOTA               COLEGIO FRANCISCO PRIMERO S.S. (IED)  URBANA
# 4  2016     BOGOTA  COL SAN JUAN VIANETH                          ...  URBANA
#
#            direccion             telefono                     nombre_Rector  \
# 0         KR 5 11 67  5665677   / 3429092                YOLANDA ARIAS CRUZ
# 1  CL 32 SUR 52 A 54              7100349              SANDRA MILENA MENDEZ
# 2     CL 134 D 47 27              6010350           CLAUDIA BOCACHICA SAENZ
# 3        KR 28 63 64   2126019 -- 2481271      JOSE CUSTODIO GALARZA MORENO
# 4    KR 2 C 3 18 SUR   2804738 -- 4714934  GLORIA ESPERANZA CHUQUIN LAISECA
#
# ...

# %% [markdown]
# 2. Mostrar las últimas 8 filas del DataFrame

# %%
data.tail(8)
# Out:
#        año secretaria                              nombreestablecimiento  \
# 2396  2016     BOGOTA  LIC PARROQ SAN GREGORIO MAGNO                 ...
# 2397  2016     BOGOTA                      COLEGIO BRASILIA - BOSA (IED)
# 2398  2016     BOGOTA                       COLEGIO ANTONIO BARAYA (IED)
# 2399  2016     BOGOTA                       COLEGIO SAN JOSE DE CALASANZ
# 2400  2016     BOGOTA                        COL NUEVO REINO DE TURINGIA
# 2401  2016     BOGOTA  LIC  INF GOOFY                                ...
# 2402  2016     BOGOTA  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  2016     BOGOTA  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#         zona             direccion                              telefono  \
# 2396  URBANA            KR 29 9 47                               2477407
# 2397  URBANA   CL 52 A SUR 87 D 45                               7831779
# 2398  URBANA     CL 27 SUR 22 A 02                     2392403 / 3668171
# ...

# %% [markdown]
# 3. Mostrar cantidad de filas y columnas del dataframe

# %%
data.shape
# Out:
# (2404, 30)

# %% [markdown]
# 4. Seleccionar la columna "zona" del Dataframe como un DataFrame, no como Serie.

# %%
data[["zona"]]
# Out:
#         zona
# 0     URBANA
# 1     URBANA
# 2     URBANA
# 3     URBANA
# 4     URBANA
# ...      ...
# 2399  URBANA
# 2400  URBANA
# 2401  URBANA
# 2402  URBANA
# 2403  URBANA
#
# [2404 rows x 1 columns]

# %% [markdown]
# 5. Seleccionar la columna "zona" del Dataframe como una Serie.

# %%
data["zona"]
# Out:
# 0       URBANA
# 1       URBANA
# 2       URBANA
# 3       URBANA
# 4       URBANA
#          ...
# 2399    URBANA
# 2400    URBANA
# 2401    URBANA
# 2402    URBANA
# 2403    URBANA
# Name: zona, Length: 2404, dtype: object

# %% [markdown]
# 6. Cambiar el nombre del índice 3 para que su valor sea obs4

# %%
data.rename(index = {3: "obs4"})
# Out:
#        año secretaria                              nombreestablecimiento  \
# 0     2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1     2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL
# 2     2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# obs4  2016     BOGOTA               COLEGIO FRANCISCO PRIMERO S.S. (IED)
# 4     2016     BOGOTA  COL SAN JUAN VIANETH                          ...
# ...    ...        ...                                                ...
# 2399  2016     BOGOTA                       COLEGIO SAN JOSE DE CALASANZ
# 2400  2016     BOGOTA                        COL NUEVO REINO DE TURINGIA
# 2401  2016     BOGOTA  LIC  INF GOOFY                                ...
# 2402  2016     BOGOTA  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  2016     BOGOTA  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#         zona             direccion                              telefono  \
# ...

# %% [markdown]
# 7. Seleccionar las columnas secretaria y zona (como indice y como string hacer el subsetting)

# %%
data.loc[:,["secretaria", "zona"]]
# Out:
#      secretaria    zona
# 0        BOGOTA  URBANA
# 1        BOGOTA  URBANA
# 2        BOGOTA  URBANA
# 3        BOGOTA  URBANA
# 4        BOGOTA  URBANA
# ...         ...     ...
# 2399     BOGOTA  URBANA
# 2400     BOGOTA  URBANA
# 2401     BOGOTA  URBANA
# 2402     BOGOTA  URBANA
# 2403     BOGOTA  URBANA
#
# [2404 rows x 2 columns]

# %%
data.iloc[:,[1,3]]
# Out:
#      secretaria    zona
# 0        BOGOTA  URBANA
# 1        BOGOTA  URBANA
# 2        BOGOTA  URBANA
# 3        BOGOTA  URBANA
# 4        BOGOTA  URBANA
# ...         ...     ...
# 2399     BOGOTA  URBANA
# 2400     BOGOTA  URBANA
# 2401     BOGOTA  URBANA
# 2402     BOGOTA  URBANA
# 2403     BOGOTA  URBANA
#
# [2404 rows x 2 columns]

# %% [markdown]
# 8. Seleccionar de la fila 10 a la 15 y las columnas secretaria y zona

# %%
data.iloc[10:16,[1,3]]
# Out:
#    secretaria    zona
# 10     BOGOTA  URBANA
# 11     BOGOTA  URBANA
# 12     BOGOTA  URBANA
# 13     BOGOTA  URBANA
# 14     BOGOTA  URBANA
# 15     BOGOTA  URBANA

# %% [markdown]
# 9. Listar todas las columnas del dataframe

# %%
data.columns
# Out:
# Index(['año', 'secretaria', 'nombreestablecimiento', 'zona', 'direccion',
#        'telefono', 'nombre_Rector', 'tipo_Establecimiento', 'etnias', 'sector',
#        'genero', 'niveles', 'jornadas', 'caracter', 'especialidad', 'grados',
#        'modelos_Educativos', 'capacidades_Excepcionales', 'discapacidades',
#        'idiomas', 'numero_de_Sedes', 'estado', 'prestador_de_Servicio',
#        'propiedad_Planta_Fisica', 'resguardo', 'matricula_Contratada',
#        'calendario', 'internado', 'estrato_Socio_Economico',
#        'correo_Electronico'],
#       dtype='object')

# %%
# Base de datos de instituciones educativas en colombia
data = pd.read_csv('https://www.datos.gov.co/api/views/qijw-htwa/rows.csv?accessType=DOWNLOAD')

# %% [markdown]
# 10. Renombrar los valores de la columna tipo_Establecimiento (buscar cuales son todos los valores únicos) para que los nombres sean 'Centro' e 'Institucion' según corresponda

# %%
data["tipo_Establecimiento"].unique()
# Out:
# array(['INSTITUCION EDUCATIVA', 'CENTRO EDUCATIVO'], dtype=object)

# %%
# busco los registros de institución educativa
filtro_institucion = data["tipo_Establecimiento"] == 'INSTITUCION EDUCATIVA'
data.loc[filtro_institucion,:]

# Reemplazo en la columna tipo_Establecimiento, 'INSTITUCION EDUCATIVA' por "Institucion"
data.loc[filtro_institucion,"tipo_Establecimiento"] = "Institucion"


# idem para centro educativo
filtro_centro = data["tipo_Establecimiento"] == 'CENTRO EDUCATIVO'
data.loc[filtro_centro,:]

data.loc[filtro_centro,"tipo_Establecimiento"] = "Centro"

data.head(3)
# Out:
#     año secretaria                              nombreestablecimiento    zona  \
# 0  2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...  URBANA
# 1  2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL  URBANA
# 2  2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA  URBANA
#
#            direccion             telefono            nombre_Rector  \
# 0         KR 5 11 67  5665677   / 3429092       YOLANDA ARIAS CRUZ
# 1  CL 32 SUR 52 A 54              7100349     SANDRA MILENA MENDEZ
# 2     CL 134 D 47 27              6010350  CLAUDIA BOCACHICA SAENZ
#
#   tipo_Establecimiento etnias  sector  ...  numero_de_Sedes estado  \
# 0          Institucion    NaN     NaN  ...                1    NaN
# 1               Centro    NaN     NaN  ...                1    NaN
# 2          Institucion    NaN     NaN  ...                1    NaN
#
#   prestador_de_Servicio  propiedad_Planta_Fisica  resguardo  \
# ...

# %%
data.loc[data["tipo_Establecimiento"] == 'INSTITUCION EDUCATIVA',"tipo_Establecimiento"] = "Institucion"
data.loc[data["tipo_Establecimiento"] == 'CENTRO EDUCATIVO',"tipo_Establecimiento"] = "Centro"
data.head(3)
# Out:
#     año secretaria                              nombreestablecimiento    zona  \
# 0  2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...  URBANA
# 1  2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL  URBANA
# 2  2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA  URBANA
#
#            direccion             telefono            nombre_Rector  \
# 0         KR 5 11 67  5665677   / 3429092       YOLANDA ARIAS CRUZ
# 1  CL 32 SUR 52 A 54              7100349     SANDRA MILENA MENDEZ
# 2     CL 134 D 47 27              6010350  CLAUDIA BOCACHICA SAENZ
#
#   tipo_Establecimiento etnias  sector  ...  numero_de_Sedes estado  \
# 0          Institucion    NaN     NaN  ...                1    NaN
# 1               Centro    NaN     NaN  ...                1    NaN
# 2          Institucion    NaN     NaN  ...                1    NaN
#
#   prestador_de_Servicio  propiedad_Planta_Fisica  resguardo  \
# ...

# %% [markdown]
# 11. Eliminar la columna resguardo del DataFrame

# %%
data.drop(
    labels = ["resguardo"],
    axis = "columns"
)
# Out:
#        año secretaria                              nombreestablecimiento  \
# 0     2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1     2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL
# 2     2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 3     2016     BOGOTA               COLEGIO FRANCISCO PRIMERO S.S. (IED)
# 4     2016     BOGOTA  COL SAN JUAN VIANETH                          ...
# ...    ...        ...                                                ...
# 2399  2016     BOGOTA                       COLEGIO SAN JOSE DE CALASANZ
# 2400  2016     BOGOTA                        COL NUEVO REINO DE TURINGIA
# 2401  2016     BOGOTA  LIC  INF GOOFY                                ...
# 2402  2016     BOGOTA  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  2016     BOGOTA  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#         zona             direccion                              telefono  \
# ...

# %% [markdown]
# 12. Contar cuantos valores únicos hay en cada columna con la función nunique

# %%
data.nunique()
# Out:
# año                             1
# secretaria                      1
# nombreestablecimiento        2387
# zona                            3
# direccion                    2377
# telefono                     2328
# nombre_Rector                2354
# tipo_Establecimiento            2
# etnias                         11
# sector                          0
# genero                          0
# niveles                        18
# jornadas                       41
# caracter                        0
# especialidad                   21
# grados                        180
# modelos_Educativos             32
# capacidades_Excepcionales       4
# discapacidades                124
# idiomas                         7
# numero_de_Sedes                 7
# estado                          0
# prestador_de_Servicio          10
# propiedad_Planta_Fisica        10
# resguardo                       2
# matricula_Contratada            2
# calendario                      3
# ...

# %% [markdown]
# 13. Mostrar un dataframe con los Rectores que esten en más de una institución

# %%
data_institucion = data.loc[data["tipo_Establecimiento"] == 'Institucion',:]
data_institucion.loc[data_institucion.duplicated(subset="nombre_Rector"),["nombre_Rector"]]
# Out:
#                       nombre_Rector
# 358     MARTHA CECILIA JIMENEZ PEÑA
# 569      MAURICIO SANABRIA GONZALEZ
# 655            MARIA RANGEL DE RIOS
# 679        JORGE ROBERTO AMAYA PAVA
# 954       FELIX EDINSON ANGEL ACUÑA
# 1058      GRACIELA RODRIGUEZ POVEDA
# 1529  LUIS FERNANDO MURCIA ANGARITA
# 1553  VICTOR MANUEL NEIRA RODRIGUEZ
# 1785       GUSTAVO MENDEZ HERNANDEZ
# 2225         ALBENIO BOLIVAR MONROY
# 2357  HNA CONCEPCION AMEZQUITA DIAZ

# %% [markdown]
# 14. Contar cuantos registros no nulos hay en cada fila y almacenarlo en un diccionario que tenga de clave el indice de la fila

# %%
dicc = {}
for indice, fila in data.iterrows():
    nulos = data.loc[indice,].isnull()
    dicc[indice] = sum(nulos)
print(dicc)
# Out:
# {0: 9, 1: 11, 2: 11, 3: 10, 4: 10, 5: 9, 6: 10, 7: 10, 8: 10, 9: 9, 10: 11, 11: 10, 12: 10, 13: 9, 14: 11, 15: 11, 16: 10, 17: 9, 18: 10, 19: 12, 20: 9, 21: 15, 22: 9, 23: 10, 24: 10, 25: 12, 26: 10, 27: 10, 28: 10, 29: 10, 30: 11, 31: 10, 32: 10, 33: 8, 34: 10, 35: 11, 36: 9, 37: 10, 38: 10, 39: 11, 40: 12, 41: 11, 42: 9, 43: 10, 44: 10, 45: 11, 46: 9, 47: 10, 48: 10, 49: 9, 50: 9, 51: 11, 52: 13, 53: 11, 54: 10, 55: 11, 56: 9, 57: 12, 58: 10, 59: 11, 60: 8, 61: 9, 62: 11, 63: 9, 64: 10, 65: 15, 66: 10, 67: 9, 68: 10, 69: 11, 70: 10, 71: 10, 72: 9, 73: 10, 74: 10, 75: 10, 76: 11, 77: 10, 78: 10, 79: 9, 80: 10, 81: 10, 82: 8, 83: 11, 84: 12, 85: 10, 86: 10, 87: 10, 88: 9, 89: 11, 90: 11, 91: 9, 92: 13, 93: 12, 94: 11, 95: 10, 96: 10, 97: 10, 98: 10, 99: 9, 100: 9, 101: 10, 102: 11, 103: 10, 104: 10, 105: 10, 106: 9, 107: 9, 108: 10, 109: 11, 110: 9, 111: 10, 112: 10, 113: 8, 114: 11, 115: 9, 116: 11, 117: 10, 118: 10, 119: 11, 120: 9, 121: 10, 122: 10, 123: 10, 124: 8, 125: 11, 126: 
# ...

# %% [markdown]
# 15. Contar cuantos registros nulos hay en cada columna y la cantidad de valores únicos en la misma, y almacenarlo en un diccionario que tenga de clave el indice el nombre de la columna

# %% [markdown]
# El output debería ser el siguiente:
# ``` sql
# {'año': [0, 1],
#  'secretaria': [0, 1],
#  'nombreestablecimiento': [0, 2387],
#  'zona': [0, 3],
#  'direccion': [0, 2377],
#  'telefono': [62, 2329],
#  'nombre_Rector': [0, 2354],
#  'tipo_Establecimiento': [0, 2],
#  'etnias': [2333, 12],
#  'sector': [2404, 1],
#  'genero': [2404, 1],
#  'niveles': [16, 19],
#  'jornadas': [13, 42],
#  'caracter': [2404, 1],
#  'especialidad': [1110, 22],
#  'grados': [16, 181],
#  'modelos_Educativos': [38, 33],
#  'capacidades_Excepcionales': [2394, 5],
#  'discapacidades': [1890, 125],
#  'idiomas': [1461, 8],
#  'numero_de_Sedes': [0, 7],
#  'estado': [2404, 1],
#  'prestador_de_Servicio': [0, 10],
#  'propiedad_Planta_Fisica': [0, 10],
#  'resguardo': [0, 2],
#  'matricula_Contratada': [0, 2],
#  'calendario': [0, 3],
#  'internado': [2404, 1],
#  'estrato_Socio_Economico': [2400, 3],
#  'correo_Electronico': [428, 1962]}
# ```

# %%
dicc = {}
for i in data.columns:
    nulos = data.loc[:,i].isnull()
    total_nulos = sum(nulos)
    
    unicos = data.loc[:,i].unique()
    total_unicos = len(unicos)

    dicc[i] = [total_nulos, total_unicos]
dicc
# Out:
# {'año': [0, 1],
#  'secretaria': [0, 1],
#  'nombreestablecimiento': [0, 2387],
#  'zona': [0, 3],
#  'direccion': [0, 2377],
#  'telefono': [62, 2329],
#  'nombre_Rector': [0, 2354],
#  'tipo_Establecimiento': [0, 2],
#  'etnias': [2333, 12],
#  'sector': [2404, 1],
#  'genero': [2404, 1],
#  'niveles': [16, 19],
#  'jornadas': [13, 42],
#  'caracter': [2404, 1],
#  'especialidad': [1110, 22],
#  'grados': [16, 181],
#  'modelos_Educativos': [38, 33],
#  'capacidades_Excepcionales': [2394, 5],
#  'discapacidades': [1890, 125],
#  'idiomas': [1461, 8],
#  'numero_de_Sedes': [0, 7],
#  'estado': [2404, 1],
#  'prestador_de_Servicio': [0, 10],
#  'propiedad_Planta_Fisica': [0, 10],
#  'resguardo': [0, 2],
#  'matricula_Contratada': [0, 2],
#  'calendario': [0, 3],
#  'internado': [2404, 1],
#  'estrato_Socio_Economico': [2400, 3],
#  'correo_Electronico': [428, 1962]}

# %% [markdown]
# 16. Realiza una copia de la data en el objeto "data_bis" para no modificar la data original y completa los valores faltantes de la columna "modelos_Educativos" con el valor del registro previo

# %%
data_bis = data.copy()

# %%
data_bis["modelos_Educativos"] = data_bis["modelos_Educativos"].ffill()

# %% [markdown]
# 17. Realiza una copia de la data en el objeto "data_bis" para no modificar la data original y completa los valores faltantes de la columna "jornadas" con el valor más frecuente de dicha columna

# %%
data_bis = data.copy()

# %%
# opcion 1
valor = data_bis["jornadas"].value_counts().index[0]
data_bis["jornadas"] = data_bis["jornadas"].fillna(valor)

# %%
# opcion 2
valor = data_bis["jornadas"].mode()
data_bis["jornadas"] = data_bis["jornadas"].fillna(valor)

# %% [markdown]
# 18. Filtrar la tabla para mostrar los registros de zona "URBANA"

# %%
data.query("zona == 'URBANA'")
# Out:
#        año secretaria                              nombreestablecimiento  \
# 0     2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1     2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL
# 2     2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 3     2016     BOGOTA               COLEGIO FRANCISCO PRIMERO S.S. (IED)
# 4     2016     BOGOTA  COL SAN JUAN VIANETH                          ...
# ...    ...        ...                                                ...
# 2399  2016     BOGOTA                       COLEGIO SAN JOSE DE CALASANZ
# 2400  2016     BOGOTA                        COL NUEVO REINO DE TURINGIA
# 2401  2016     BOGOTA  LIC  INF GOOFY                                ...
# 2402  2016     BOGOTA  LIC APRENDO CON MIS AMIGOS                    ...
# 2403  2016     BOGOTA  JARD INF EL ROSAL DE MI INFANCIA              ...
#
#         zona             direccion                              telefono  \
# ...

# %% [markdown]
# 19. Filtrar la tabla para mostrar los registros que no sean de calendario "A" y tengan menos de 5 sedes o por lo menos más de 1

# %%
data.query("calendario != 'A' and numero_de_Sedes >= 1 and numero_de_Sedes <= 5")
# Out:
#        año secretaria                              nombreestablecimiento  \
# 79    2016     BOGOTA  COL COLOMBO HEBREO                            ...
# 94    2016     BOGOTA                                 INSTITUTO EL ROBLE
# 156   2016     BOGOTA  JARD INF MI PEQUEÑO MUNDO BARRETO GOMEZ Y CIA ...
# 169   2016     BOGOTA  JARD INF TALLER DE ARTE ARCO IRIS             ...
# 170   2016     BOGOTA  COL COOP MINUTO DE DIOS                       ...
# ...    ...        ...                                                ...
# 2274  2016     BOGOTA  FUND NUEVO MARYMOUNT                          ...
# 2282  2016     BOGOTA                                      COL CALATRAVA
# 2291  2016     BOGOTA  COL  MONTESSORI BRITISH SCHOOL                ...
# 2331  2016     BOGOTA  COL ABRAHAM LINCOLN                           ...
# 2347  2016     BOGOTA  COL. INTERNACIONAL DE EDUCACIÓN INTEGRAL - CIE...
#
#         zona            direccion  \
# 79    URBANA         AC 153 50 65
# ...

# %% [markdown]
# 20. Filtrar la tabla para mostrar los registros que no tenga nulo la columna "niveles" y que no sea un registro que se encuentre posterior a la mitad de la tabla

# %%
# opcion 1
data.iloc[:int(data.shape[0]/2),:].dropna(subset=['niveles'])

# opcion 2
data.iloc[:int(data.shape[0]/2),:].query('niveles.notnull()')
# Out:
#        año secretaria                              nombreestablecimiento  \
# 0     2016     BOGOTA  INST DE BTO TEC COMERCIAL PITAGORAS           ...
# 1     2016     BOGOTA                 GIMNASIO INFANTIL FEDERICO FROEBEL
# 2     2016     BOGOTA             GIMNASIO INFANTIL LOS NIÑOS DEL MAÑANA
# 3     2016     BOGOTA               COLEGIO FRANCISCO PRIMERO S.S. (IED)
# 4     2016     BOGOTA  COL SAN JUAN VIANETH                          ...
# ...    ...        ...                                                ...
# 1197  2016     BOGOTA  LIC PEDAG LOS JILGUEROS                       ...
# 1198  2016     BOGOTA                        COLEGIO CAMPESTRE LOS PINOS
# 1199  2016     BOGOTA  GIMN PSICOPEDAG GENESIS                       ...
# 1200  2016     BOGOTA  COL NSTRA SRA DE LA SALINA                    ...
# 1201  2016     BOGOTA  COL DE NSTRA SRA DEL ROSARIO                  ...
#
#         zona            direccion  \
# 0     URBANA           KR 5 11 67
# ...
